# %% [markdown]
# # Úvod do práce s knihovnou Pandas

# %% [markdown]
# [Pandas](https://pandas.pydata.org/) je open-source knihovna v jazyce Python, která slouží pro jednoduchou práci s daty v růzuných formátek. Umožňuje snadné načítání, manipulaci a jednoduché analýzy. Pro použití stačí naimportovat balíček *pandas*.

# %%
import pandas as pd

# %% [markdown]
# Pandas obsahuje dvě základní datové struktury - [Series](https://pandas.pydata.org/pandas-docs/dev/reference/api/pandas.Series.html) a [DataFrame](https://pandas.pydata.org/pandas-docs/dev/reference/frame.html), které si dále přiblížíme.

# %% [markdown]
# ## Series
#
# Series je jednodimenzionální objekt podobný datové struktuře [list](https://docs.python.org/3/tutorial/datastructures.html) v pythonu nebo sloupci v relačních databázích. Každé jeho položce je při vytvoření automaticky přiřazen index (celé číslo od 0 do n, kde n je počet položek minus 1).

# %%
s = pd.Series([1, 2, 3.14, "Karel"])
s
# Out:
# 0        1
# 1        2
# 2     3.14
# 3    Karel
# dtype: object

# %% [markdown]
# Pokud chceme použít jiné indexy než ty automatické, je třeba je definovat při vytváření objektu.

# %%
vysky = pd.Series([1603, 1491, 1378], index = ["Snezka", "Praded", "Plechy"])
vysky
# Out:
# Snezka    1603
# Praded    1491
# Plechy    1378
# dtype: int64

# %% [markdown]
# Případně je možné pro vytvoření objektu použít datovou strukturu [dictionary](https://docs.python.org/3/tutorial/datastructures.html).

# %%
vysky = pd.Series({"Snezka": 1603, "Praded": 1491, "Plechy": 1378})
vysky
# Out:
# Snezka    1603
# Praded    1491
# Plechy    1378
# dtype: int64

# %% [markdown]
# Index je potom možné použít pro přístup k jednotlivým položkám.

# %%
vysky["Snezka"]
# Out:
# 1603

# %% [markdown]
# Pro výběr položek je možné použít i podmínky.

# %%
vysky[vysky > 1400]
# Out:
# Snezka    1603
# Praded    1491
# dtype: int64

# %% [markdown]
# Matematické operace je možné aplikovat na všechny položky najednou.

# %%
vysky_v_kilometrech = vysky / 1000
vysky_v_kilometrech
# Out:
# Snezka    1.603
# Praded    1.491
# Plechy    1.378
# dtype: float64

# %% [markdown]
# ## DataFrame
#
# DataFrame je datová struktura podobná tabulce relační databáze nebo tabulce v Excelu. V zásadě jde o skupinu objektů Series, které mají společný index.

# %%
data = {
    "pohori": ["Krkonose", "Jeseniky", "Sumava"],
    "hora": ["Snezka", "Praded", "Plechy"],
    "vyska": [1603, 1491, 1378]
}
df = pd.DataFrame(data, columns = ["pohori", "hora", "vyska"])
df
# Out:
#      pohori    hora  vyska
# 0  Krkonose  Snezka   1603
# 1  Jeseniky  Praded   1491
# 2    Sumava  Plechy   1378

# %% [markdown]
# Nejčastnějším způsobem vytvoření DataFramu je načtení ze souboru. Nepovinný parametr "sep" označuje použitý oddělovač sloupců v CSV souboru.

# %%
csv_data = pd.read_csv('data/nehody_cyklistu.csv', sep=';')
csv_data
# Out:
#                        datum                                      srazka  \
# 0     2013/10/16 00:00:00+00      srážka s jedoucím nekolejovým vozidlem
# 
# 25             řidičem motorového vozidla
# 26           řidičem nemotorového vozidla
# 27           řidičem nemotorového vozidla
# 28             řidičem motorového vozidla
# 29             řidičem motorového vozidla
# ...                                   ...
# 1140         řidičem nemotorového vozidla
# 1141         řidičem nemotorového vozidla
# 1142         řidičem nemotorového vozidla
# 1143           řidičem motorového vozidla
# 1144           řidičem motorového vozidla
# 1145         řidičem nemotorového vozidla
# 1146         řidičem nemotorového vozidla
# 1147           řidičem motorového vozidla
# 1148         řidičem nemotorového vozidla
# 1149         řidičem nemotorového vozidla
# 1150           řidičem motorového vozidla
# 1151  jiným účastníkem silničního provozu
# 1152           řidičem motorového vozidla
# 1153           řidičem motorového vozidla
# 1154         řidičem nemotorového vozidla
# 1155         řidičem nemotorového vozidla
# 1156           řidičem motorového vozidla
# 1157         řidičem nemotorového vozidla
# 1158           řidičem motorového vozidla
# 1159                   závadou komunikace
# 1160           řidičem motorového vozidla
# 1161           řidičem motorového vozidla
# 1162         řidičem nemotorového vozidla
# 1163         řidičem nemotorového vozidla
# 1164           řidičem motorového vozidla
# 1165           řidičem motorového vozidla
# 1166         řidičem nemotorového vozidla
# 1167         řidičem nemotorového vozidla
# 1168         řidičem nemotorového vozidla
# 1169         řidičem nemotorového vozidla
#
#                                          alkohol       nasledek prilba pohlavi
# 0     Ano, obsah alkoholu v krvi od 0,5‰ do 0,8‰  lehké zranění    ano     muž
# 1                                             Ne  lehké zranění     ne     muž
# 2         Ano, obsah alkoholu v krvi 1,5‰ a více  lehké zranění     ne     muž
# 3         Ano, obsah alkoholu v krvi 1,5‰ a více  lehké zranění     ne     muž
# 4         Ano, obsah alkoholu v krvi 1,5‰ a více  lehké zranění     ne     muž
# 5         Ano, obsah alkoholu v krvi 1,5‰ a více     bez zraněn     ne     muž
# 6         Ano, obsah alkoholu v krvi 1,5‰ a více  lehké zranění     ne    žena
# 7         Ano, obsah alkoholu v krvi 1,5‰ a více  lehké zranění     ne     muž
# 8         Ano, obsah alkoholu v krvi 1,5‰ a více  lehké zranění    ano     muž
# 9     Ano, obsah alkoholu v krvi od 1,0‰ do 1,5‰  lehké zranění     ne     muž
# 10                                   Nezjišťován  lehké zranění     ne     muž
# 11        Ano, obsah alkoholu v krvi 1,5‰ a více  lehké zranění     ne     muž
# 12        Ano, obsah alkoholu v krvi 1,5‰ a více  lehké zranění     ne     muž
# 13    Ano, obsah alkoholu v krvi od 1,0‰ do 1,5‰  lehké zranění     ne     muž
# 14                                   Nezjišťován  lehké zranění     ne    žena
# 15                                   Nezjišťován  těžké zranění     ne     muž
# 16                                            Ne  lehké zranění     ne    žena
# 17                                            Ne  lehké zranění    ano     muž
# 18                                            Ne  lehké zranění     ne     muž
# 19                                   Nezjišťován     bez zraněn    ano     muž
# 20                                   Nezjišťován  lehké zranění    ano     muž
# 21                                   Nezjišťován     bez zraněn     ne     muž
# 22                                            Ne  lehké zranění    ano     muž
# 23                                   Nezjišťován     bez zraněn    ano     muž
# 24                                            Ne  lehké zranění    ano     muž
# 25                                            Ne  lehké zranění     ne    žena
# 26                                            Ne  lehké zranění    ano    žena
# 27                                            Ne  lehké zranění    ano     muž
# 28                                            Ne  lehké zranění    ano     muž
# 29                                            Ne  lehké zranění     ne     muž
# ...                                          ...            ...    ...     ...
# 1140                                 Nezjišťován  těžké zranění     ne     muž
# 1141                                          Ne  lehké zranění     ne     muž
# 1142                                          Ne  lehké zranění     ne     muž
# 1143                                          Ne  lehké zranění    ano     muž
# 1144                                 Nezjišťován  lehké zranění     ne     muž
# 1145                                          Ne  těžké zranění    ano    žena
# 1146                                          Ne  lehké zranění    ano     muž
# 1147                                 Nezjišťován  lehké zranění     ne    žena
# 1148      Ano, obsah alkoholu v krvi 1,5‰ a více  lehké zranění     ne    žena
# 1149                                          Ne  lehké zranění    ano    žena
# 1150                                          Ne  lehké zranění     ne     muž
# 1151                                 Nezjišťován  těžké zranění     ne     muž
# 1152                                          Ne  lehké zranění     ne     muž
# 1153                                          Ne  lehké zranění    ano     muž
# 1154                                          Ne  lehké zranění    ano    žena
# 1155                                          Ne  lehké zranění     ne     muž
# 1156                                          Ne  lehké zranění    ano     muž
# 1157                                          Ne  lehké zranění     ne     muž
# 1158                                          Ne  lehké zranění    ano     muž
# 1159                                 Nezjišťován  lehké zranění    ano     muž
# 1160                                          Ne  lehké zranění     ne     muž
# 1161                                          Ne  lehké zranění     ne     muž
# 1162                                          Ne  lehké zranění    ano     muž
# 1163                             Pod vlivem drog  lehké zranění     ne     muž
# 1164                                          Ne  lehké zranění     ne     muž
# 1165                                          Ne  lehké zranění    ano     muž
# 1166                                          Ne  lehké zranění     ne    žena
# 1167                                          Ne  lehké zranění    ano    žena
# 1168        Ano, obsah alkoholu v krvi do 0,24 ‰  lehké zranění    ano    žena
# 1169                                          Ne  lehké zranění    ano     muž
#
# [1170 rows x 7 columns]

# %% [markdown]
# Pro rychlý náhled na data se hodí metoda _head(n)_, která zobrazí pouze prvních _n_ položek. Pokud parametr _n_ nepoužijeme, zobrazí se prvních 5.

# %%
csv_data.head(3)
# Out:
#                     datum                                  srazka  \
# 0  2013/10/16 00:00:00+00  srážka s jedoucím nekolejovým vozidlem
# 1  2014/06/14 00:00:00+00                        srážka s chodcem
# 2  2014/08/13 00:00:00+00                                 havárie
#
#                        zavineni                                     alkohol  \
# 0    řidičem motorového vozidla  Ano, obsah alkoholu v krvi od 0,5‰ do 0,8‰
# 1                       chodcem                                          Ne
# 2  řidičem nemotorového vozidla      Ano, obsah alkoholu v krvi 1,5‰ a více
#
#         nasledek prilba pohlavi
# 0  lehké zranění    ano     muž
# 1  lehké zranění     ne     muž
# 2  lehké zranění     ne     muž

# %% [markdown]
# Pro zapsání uložení DataFramu ve formátu CSV na disk slouží metoda *to_csv(nazev_souboru.csv)*.

# %%
df.to_csv("/tmp/vysky.csv")

# %%
# !ls /tmp/
# Out:
# com.adobe.reader.rna.0.1f5.DC com.apple.launchd.yn7wtIJULC
# com.adobe.reader.rna.37a.1f5  powerlog
# com.apple.launchd.rFtFo6bocN  vysky.csv

# %% [markdown]
# Pro získání jednoho nebo více sloupců slouží závorková notace.

# %%
df['vyska']
# Out:
# 0    1603
# 1    1491
# 2    1378
# Name: vyska, dtype: int64

# %%
df[['hora', 'vyska']]
# Out:
#      hora  vyska
# 0  Snezka   1603
# 1  Praded   1491
# 2  Plechy   1378
